# %%
import torch
import torch.nn as nn
import torch.nn.utils.prune as prune
import torchvision.models as models

# %%
module = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=(3,3))

# %%
prune.ln_structured(module, name="weight", amount=0.5, n=2, dim=0)
# Out:
# Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))

# %%
module.weight
# Out:
# tensor([[[[-0.0000, -0.0000, -0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000,  0.0000]],
#
#          [[-0.0000,  0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[ 0.1785, -0.1884, -0.1030],
#           [-0.1203,  0.1706,  0.0156],
#           [-0.0315, -0.1708,  0.0025]],
#
#          [[-0.1757, -0.1552, -0.1521],
#           [ 0.0340, -0.0533,  0.0835],
#           [-0.1748, -0.1707, -0.1481]],
#
#          [[ 0.0495,  0.1886,  0.0743],
#           [ 0.1047, -0.0209,  0.0626],
#           [-0.0389, -0.0769,  0.0822]]],
#
#
#         [[[-0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[ 0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000]],
#
#          [[-0.0000, -0.0000, -0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[-0.1741,  0.1326,  0.1679],
#           [ 0.0787, -0.0251,  0.1917],
#           [-0.1862, -0.1561,  0.1879]],
#
#          [[ 0.1188, -0.1584,  0.0529],
#           [-0.0196, -0.0864,  0.1136],
#           [ 0.0109,  0.0818,  0.1077]],
#
#          [[-0.1133, -0.0859, -0.1738],
#           [ 0.0139,  0.0364, -0.0776],
#           [-0.0595,  0.0355, -0.0156]]],
#
#
#         [[[-0.0950,  0.1755,  0.0022],
#           [ 0.0815, -0.1389, -0.0027],
#           [-0.1389,  0.0841,  0.0552]],
#
#          [[-0.0685,  0.0561, -0.0233],
#           [ 0.0860,  0.1437,  0.0205],
#           [-0.1541,  0.1686, -0.1781]],
#
#          [[ 0.1110, -0.0742, -0.1324],
#           [-0.1080, -0.1428, -0.0923],
#           [-0.1557,  0.0694, -0.1753]]],
#
#
#         [[[-0.0000, -0.0000, -0.0000],
#           [-0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000, -0.0000]],
#
#          [[ 0.0000,  0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[-0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000,  0.0000,  0.0000]]]], grad_fn=<MulBackward0>)

# %%
module.weight
# Out:
# tensor([[[[-0.0000, -0.0000, -0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000,  0.0000]],
#
#          [[-0.0000,  0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[ 0.1785, -0.1884, -0.1030],
#           [-0.1203,  0.1706,  0.0156],
#           [-0.0315, -0.1708,  0.0025]],
#
#          [[-0.1757, -0.1552, -0.1521],
#           [ 0.0340, -0.0533,  0.0835],
#           [-0.1748, -0.1707, -0.1481]],
#
#          [[ 0.0495,  0.1886,  0.0743],
#           [ 0.1047, -0.0209,  0.0626],
#           [-0.0389, -0.0769,  0.0822]]],
#
#
#         [[[-0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[ 0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000]],
#
#          [[-0.0000, -0.0000, -0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[-0.1741,  0.1326,  0.1679],
#           [ 0.0787, -0.0251,  0.1917],
#           [-0.1862, -0.1561,  0.1879]],
#
#          [[ 0.1188, -0.1584,  0.0529],
#           [-0.0196, -0.0864,  0.1136],
#           [ 0.0109,  0.0818,  0.1077]],
#
#          [[-0.1133, -0.0859, -0.1738],
#           [ 0.0139,  0.0364, -0.0776],
#           [-0.0595,  0.0355, -0.0156]]],
#
#
#         [[[-0.0950,  0.1755,  0.0022],
#           [ 0.0815, -0.1389, -0.0027],
#           [-0.1389,  0.0841,  0.0552]],
#
#          [[-0.0685,  0.0561, -0.0233],
#           [ 0.0860,  0.1437,  0.0205],
#           [-0.1541,  0.1686, -0.1781]],
#
#          [[ 0.1110, -0.0742, -0.1324],
#           [-0.1080, -0.1428, -0.0923],
#           [-0.1557,  0.0694, -0.1753]]],
#
#
#         [[[-0.0000, -0.0000, -0.0000],
#           [-0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000, -0.0000]],
#
#          [[ 0.0000,  0.0000, -0.0000],
#           [-0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0000, -0.0000]],
#
#          [[-0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000,  0.0000,  0.0000]]]], grad_fn=<MulBackward0>)
